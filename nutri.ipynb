# %%
import requests 
from bs4 import BeautifulSoup, Tag
import pandas as pd

# %%
# Parsear el codigo source de la página 
url = "https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Aceite"

page = requests.get(url).text

pageSoup = BeautifulSoup(page, "html.parser")

# %%
pageSoup.prettify

# %%
# Filtrar para encontrar la tabla 
tabla = pageSoup.find("td", class_="leftCell")

# %%
# Encontrar todos los Nombres de Productos
Productos = tabla.find_all("a",class_="prominent")
Producto = []

for caracter in Productos:
    Producto.append(caracter.text)
    
Producto

# %%
# Encontrar los nombres de Marcas
Marcas = tabla.find_all("a",class_="brand")
Marca = []
for caracter in Marcas:
    marca_texto = caracter.text.replace("(", "").replace(")", "")
    Marca.append(marca_texto)

Marca

# %%
# Encontrar las cantidades
Cantidades = tabla.find_all("div",class_="smallText greyText greyLink")
Cantidad = []
for caracter in Cantidades:
    cantidad_texto = caracter.text.replace("\r", "").replace("\n", "").replace("\t", "")
    cantidad_texto = cantidad_texto.split("-", 1)[0]
    Cantidad.append(cantidad_texto)

Cantidad

# %%
# Encontrar las Calorias
Calorias = tabla.find_all("div", class_="smallText greyText greyLink")
Caloria = []
for caracter in Calorias:
    calorias_texto = caracter.text.replace("\r", "").replace("\n", "").replace("\t", "")
    calorias_texto = calorias_texto.split("-", 1)[-1].split("|")[0].strip().replace("Calorías:", "")
    Caloria.append(calorias_texto.strip())



Caloria

# %%
# Encontrar las Grasas
Grasas = tabla.find_all("div", class_="smallText greyText greyLink")
Grasa = []
for caracter in Grasas:
    grasas_texto = caracter.text.replace("\r", "").replace("\n", "").replace("\t", "")
    grasas_texto = grasas_texto.split("|", 1)[-1].split("|")[0].strip().replace("Grasa:", "")
    Grasa.append(grasas_texto.strip())

Grasa

# %%
# Encontrar los Carbohidratos
Carbohidratos = tabla.find_all("div", class_="smallText greyText greyLink")
Carbohidrato = []
for caracter in Carbohidratos:
    carbohidratos_texto = caracter.text.replace("\r", "").replace("\n", "").replace("\t", "")
    carbohidratos_aexto = carbohidratos_texto.split("|", 2)[-1].split("|")[0].strip().replace("Carbh:", "")
    Carbohidrato.append(carbohidratos_texto.strip())

Carbohidrato

# %%
# Encontrar las Proteinas
Proteinas = tabla.find_all("div", class_="smallText greyText greyLink")
Proteina = []
for caracter in Proteinas:
    proteinas_texto = caracter.text.replace("\r", "").replace("\n", "").replace("\t", "")
    proteinas_texto = proteinas_texto.split("|", 3)[-1].split("|")[0].strip().replace("Prot:", "")
    proteinas_texto = proteinas_texto.split("g", 1)[0] + "g"
    Proteina.append(proteinas_texto.strip())

Proteina

# %%
columnas = ["Producto","Marca","Cantidad","Caloria","Grasa","Carbohidrato","Proteina"]
data_ = list(zip(Producto, Marca, Cantidad, Caloria, Grasa, Carbohidrato, Proteina))
df = pd.DataFrame(columns=columnas,data=data_)

# %%
Tabla_Nutricional_Productos = pd.concat([Tabla_Nutricional_Productos,df],ignore_index=True)

# %%
# Generar las Columnas y la Data para luego insertarla en un DataFrame
columnas = ["Producto","Marca","Cantidad","Caloria","Grasa","Carbohidrato","Proteina"]

data_ = list(zip(Producto, Marca, Cantidad, Caloria, Grasa, Carbohidrato, Proteina))
Tabla_Nutricional_Productos = pd.DataFrame(columns= columnas,data=data_)

# %%
Tabla_Nutricional_Productos

# %%
ñom = requests.get("https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Leche+Descremada&pg=6").text
pagsigSoup = BeautifulSoup(ñom,"html.parser")

# %%
paginassiguiente = pagsigSoup.find("div", class_="searchResultsPaging")
paginassiguiente = paginassiguiente.find_all("a")
pagsig = []
base_url = "https://www.fatsecret.com.ar"
for link in paginassiguiente[1:-1]:
    pagsig.append(base_url + link['href'])

# %%
pagsig

# %%
elementos = ["Aceite","Vinagre","Pasta","Arroz","Legumbre","Semilla","Harina","Premezcla+salada","Polenta","Avena","Atun","Caballa","Paté","Anchoa","Salsa+de+tomate","Salsa","Choclo","Arvejas","Lenteja","Poroto","Garbanzos","Chaucha","Palmitos","Frijoles","Aceitunas","Caldos","Sopas","Purés+instantaneos","Premezclas","Coberturas","Rellenos","Gelatinas","Postres","Dulce+de+Leche","Nutella","Mermeladas","Papas+fritas","Snacks de maiz","Nachos","Maní","Palitos","Galletitas dulces","Bizcochitos","Galletitas de agua","Galletas de arroz","Tostadas","Grisines","Budines","Magdalenas","Yerba","Café","Té","Mate Cocido","Cacao","Azúcar","Edulcorantes","Endulzantes","Cereales","Barritas de cereales","Granola","Chocolates","Alfajores","Caramelos","Gomitas","Chupetines","Bocaditos","Confites","Turrones","Leche entera","Leche descremada","Leche vegetal","Leche en polvo","Yogures enteros","Yogures descremados","Manteca","Levadura","Cremas de leche","Huevos","Tapas","Dulce de membrillo","Dulce de batata","Salchichas","Quesos","Fiambres","Carne vacuna","Pollo","Carne de cerdo","Anchuras","embutidos","Pescados","Mariscos","Frutas","Verduras","Frutos secos","Pan","Pan rallado","Hamburgesas+congeladas","Nuggets congeladas","Papas congeladas","Helado"]
for i in range(len(elementos)):
    if " " in elementos[i]:
        elementos[i] = elementos[i].replace(" ", "+")

ñomis = []
for e in elementos:
    ñomis.append(f"https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q={e}")

for url in ñomis:
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")
    tabla_busqueda = soup.find("div",class_="searchResultsPaging")
    if tabla_busqueda is not None:
        res = tabla_busqueda.find_all("a")
        res = [tag.text if isinstance(tag, Tag) else tag for tag in res]
        if "Siguiente" in res:
            res.remove("Siguiente")
        res_int = [int(val) for val in res]
        max_pag = max(res_int)
        link = url + f"&pg={max_pag}"
        print(link)
    else:
        print(f"No search results found for {url}")
# Out:
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Aceite&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Vinagre&pg=2
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Pasta&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Arroz&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Legumbre&pg=2
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Semilla&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Harina&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Premezcla+salada&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Polenta&pg=2
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Avena&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Atun&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Caballa&pg=4
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Paté&pg=3
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Anchoa&pg=1
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Salsa+de+tomate&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Salsa&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Choclo&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Arvejas&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Lenteja&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Poroto&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Garbanzos&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Chaucha&pg=2
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Palmitos&pg=4
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Frijoles&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Aceitunas&pg=3
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Caldos&pg=4
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Sopas&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Purés+instantaneos&pg=5
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Premezclas&pg=1
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Coberturas&pg=1
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Rellenos&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Gelatinas&pg=5
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Postres&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Dulce+de+Leche&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Nutella&pg=1
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Mermeladas&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Papas+fritas&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Snacks+de+maiz&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Nachos&pg=2
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Maní&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Palitos&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Galletitas+dulces&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Bizcochitos&pg=2
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Galletitas+de+agua&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Galletas+de+arroz&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Tostadas&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Grisines&pg=3
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Budines&pg=1
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Magdalenas&pg=5
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Yerba&pg=3
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Café&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Té&pg=5
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Mate+Cocido&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Cacao&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Azúcar&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Edulcorantes&pg=2
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Endulzantes&pg=1
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Cereales&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Barritas+de+cereales&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Granola&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Chocolates&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Alfajores&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Caramelos&pg=5
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Gomitas&pg=3
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Chupetines&pg=1
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Bocaditos&pg=4
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Confites&pg=2
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Turrones&pg=1
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Leche+entera&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Leche+descremada&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Leche+vegetal&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Leche+en+polvo&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Yogures+enteros&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Yogures+descremados&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Manteca&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Levadura&pg=2
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Cremas+de+leche&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Huevos&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Tapas&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Dulce+de+membrillo&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Dulce+de+batata&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Salchichas&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Quesos&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Fiambres&pg=2
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Carne+vacuna&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Pollo&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Carne+de+cerdo&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Anchuras&pg=1
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=embutidos&pg=1
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Pescados&pg=3
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Mariscos&pg=3
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Frutas&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Verduras&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Frutos+secos&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Pan&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Pan+rallado&pg=1
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Hamburgesas+congeladas&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Nuggets+congeladas&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Papas+congeladas&pg=6
# https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Helado&pg=6

# %%
ñomis

# %%
for i in range(0,len(ñomis)):
    url = ñomis[i]
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")

    # Find the first "a" tag with class "strong"
    tabla_busqueda = soup.find("div",class_="searchResultsPaging")
    if tabla_busqueda is not None:
        res = tabla_busqueda.find_all("a")
        # Only access the text attribute if the element is a tag
        res = [tag.text if isinstance(tag, Tag) else tag for tag in res]
        print(res)
    else:
        print(f"No search results found for {url}")

# %%
elementos = ["Aceite","Vinagre","Pasta","Arroz","Legumbre","Semilla","Harina","Premezcla+salada","Polenta","Avena","Atun","Caballa","Paté","Anchoa","Salsa+de+tomate","Salsa","Choclo","Arvejas","Lenteja","Poroto","Garbanzos","Chaucha","Palmitos","Frijoles","Aceitunas","Caldos","Sopas","Purés+instantaneos","Premezclas","Coberturas","Rellenos","Gelatinas","Postres","Dulce+de+Leche","Nutella","Mermeladas","Papas+fritas","Snacks de maiz","Nachos","Maní","Palitos","Galletitas dulces","Bizcochitos","Galletitas de agua","Galletas de arroz","Tostadas","Grisines","Budines","Magdalenas","Yerba","Café","Té","Mate Cocido","Cacao","Azúcar","Edulcorantes","Endulzantes","Cereales","Barritas de cereales","Granola","Chocolates","Alfajores","Caramelos","Gomitas","Chupetines","Bocaditos","Confites","Confites","Turrones","Leche entera","Leche descremada","Leche vegetal","Leche en polvo","Yogures enteros","Yogures descremados","Manteca","Levadura","Cremas de leche","Huevos","Tapas","Dulce de membrillo","Dulce de batata","Salchichas","Quesos","Fiambres","Carne vacuna","Pollo","Carne de cerdo","Anchuras","embutidos","Pescados","Mariscos","Frutas","Verduras","Frutos secos","Panificado","Pan rallado","Hamburguesas congeladas","Nuggets congeladas","Papas congeladas","Helado"]

for i in range(len(elementos)):
    if " " in elementos[i]:
        elementos[i] = elementos[i].replace(" ", "+")

ñomis = []
for e in elementos:
    ñomis.append(f"https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q={e}&pg=6")

ñomis

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup, Tag



def Scraper_v2():
    elementos = ["Aceite","Vinagre","Pasta","Arroz","Legumbre","Semilla","Harina","Premezcla+salada","Polenta","Avena","Atun","Caballa","Paté","Anchoa","Salsa+de+tomate","Salsa","Choclo","Arvejas","Lenteja","Poroto","Garbanzos","Chaucha","Palmitos","Frijoles","Aceitunas","Caldos","Sopas","Purés+instantaneos","Premezclas","Coberturas","Rellenos","Gelatinas","Postres","Dulce+de+Leche","Nutella","Mermeladas","Papas+fritas","Snacks de maiz","Nachos","Maní","Palitos","Galletitas dulces","Bizcochitos","Galletitas de agua","Galletas de arroz","Tostadas","Grisines","Budines","Magdalenas","Yerba","Café","Té","Mate Cocido","Cacao","Azúcar","Edulcorantes","Endulzantes","Cereales","Barritas de cereales","Granola","Chocolates","Alfajores","Caramelos","Gomitas","Chupetines","Bocaditos","Confites","Turrones","Leche entera","Leche descremada","Leche vegetal","Leche en polvo","Yogures enteros","Yogures descremados","Manteca","Levadura","Cremas de leche","Huevos","Tapas","Dulce de membrillo","Dulce de batata","Salchichas","Quesos","Fiambres","Carne vacuna","Pollo","Carne de cerdo","Anchuras","embutidos","Pescados","Mariscos","Frutas","Verduras","Frutos secos","Pan","Pan rallado","Nuggets congeladas","Papas congeladas","Helado"]
    for i in range(len(elementos)):
        if " " in elementos[i]:
            elementos[i] = elementos[i].replace(" ", "+")

    ñomis = []
    for e in elementos:
        ñomis.append(f"https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q={e}")

    Tabla_Nutricional_Productos = pd.DataFrame()
    
    for url in ñomis:
        page = requests.get(url)
        soup = BeautifulSoup(page.content, "html.parser")
        tabla_busqueda = soup.find("div",class_="searchResultsPaging")
        if tabla_busqueda is not None:
            res = tabla_busqueda.find_all("a")
            res = [tag.text if isinstance(tag, Tag) else tag for tag in res]
            if "Siguiente" in res:
                res.remove("Siguiente")
            res_int = [int(val) for val in res]
            max_pag = max(res_int)
            link = url + f"&pg={max_pag}"
            url = link
            page = requests.get(url).text
            pageSoup = BeautifulSoup(page, "html.parser")
            tabla = pageSoup.find("td", class_="leftCell")

            # Encontrar todos los Nombres de Productos
            Productos = tabla.find_all("a",class_="prominent")
            Producto = []
            for caracter in Productos:
                Producto.append(caracter.text)
           
            Marcas = tabla.find_all("a",class_="brand")
            Marca = []
            for caracter in Marcas:
                marca_texto = caracter.text.replace("(", "").replace(")", "")
                Marca.append(marca_texto)

            # Check if there are as many brands as products
            if len(Marca) < len(Producto):
                #Append None for missing brands
                Marca += [None] * (len(Producto) - len(Marca))
            
            # Encontrar las cantidades
            Cantidades = tabla.find_all("div",class_="smallText greyText greyLink")
            Cantidad = []
            for caracter in Cantidades:
                cantidad_texto = caracter.text.replace("\r", "").replace("\n", "").replace("\t", "")
                cantidad_texto = cantidad_texto.split("-", 1)[0]
                Cantidad.append(cantidad_texto)
           
            # Encontrar las Calorias
            Calorias = tabla.find_all("div", class_="smallText greyText greyLink")
            Caloria = []
            for caracter in Calorias:
                calorias_texto = caracter.text.replace("\r", "").replace("\n", "").replace("\t", "")
                calorias_texto = calorias_texto.split("-", 1)[-1].split("|")[0].strip().replace("Calorías:", "")
                Caloria.append(calorias_texto.strip())
           
            # Encontrar las Grasas
            Grasas = tabla.find_all("div", class_="smallText greyText greyLink")
            Grasa = []
            for caracter in Grasas:
                grasas_texto = caracter.text.replace("\r", "").replace("\n", "").replace("\t", "")
                grasas_texto = grasas_texto.split("|", 1)[-1].split("|")[0].strip().replace("Grasa:", "")
                Grasa.append(grasas_texto.strip())
           
            # Encontrar los Carbohidratos
            Carbohidratos = tabla.find_all("div", class_="smallText greyText greyLink")
            Carbohidrato = []
            for caracter in Carbohidratos:
                carbohidratos_texto = caracter.text.replace("\r", "").replace("\n", "").replace("\t", "")
                carbohidratos_texto = carbohidratos_texto.split("|", 2)[-1].split("|")[0].strip().replace("Carbh:", "")
                Carbohidrato.append(carbohidratos_texto.strip())
           
            # Encontrar las Proteinas
            Proteinas = tabla.find_all("div", class_="smallText greyText greyLink")
            Proteina = []
            for caracter in Proteinas:
                proteinas_texto = caracter.text.replace("\r", "").replace("\n", "").replace("\t", "")
                proteinas_texto = proteinas_texto.split("|", 3)[-1].split("|")[0].strip().replace("Prot:", "")
                proteinas_texto = proteinas_texto.split("g", 1)[0] + "g"
                Proteina.append(proteinas_texto.strip())
        
        
            if not Tabla_Nutricional_Productos.empty:
                columnas = ["Producto","Marca","Cantidad","Caloria","Grasa","Carbohidrato","Proteina"]
                data_ = list(zip(Producto, Marca, Cantidad, Caloria, Grasa, Carbohidrato, Proteina))
                df = pd.DataFrame(columns=columnas,data=data_)
                Tabla_Nutricional_Productos = pd.concat([Tabla_Nutricional_Productos,df],ignore_index=True)
            else:
                columnas = ["Producto","Marca","Cantidad","Caloria","Grasa","Carbohidrato","Proteina"]
                data_ = list(zip(Producto, Marca, Cantidad, Caloria, Grasa, Carbohidrato, Proteina))
                Tabla_Nutricional_Productos = pd.DataFrame(columns= columnas,data=data_)
            
    return Tabla_Nutricional_Productos

# %%
Scraper_v2()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 Scraper_v2()
#
# Cell In[50], line 37, in Scraper_v2()
#      34 tabla = pageSoup.find("td", class_="leftCell")
#      36 # Encontrar todos los Nombres de Productos
# ---> 37 Productos = tabla.find_all("a",class_="prominent")
#      38 Producto = []
#      39 for caracter in Productos:
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup



def Scraper(url_):
    url_ = requests.get(url_).text
    pagsigSoup = BeautifulSoup(url_,"html.parser") 
    paginassiguiente = pagsigSoup.find("div", class_="searchResultsPaging")
    paginassiguiente = paginassiguiente.find_all("a")
    pagsig = []
    base_url = "https://www.fatsecret.com.ar"
    for link in paginassiguiente[1:-1]:
        pagsig.append(base_url + link['href'])

    Tabla_Nutricional_Productos = pd.DataFrame()
    
    for i in range(0,(len(pagsig))):
        url = pagsig[i]
        page = requests.get(url).text
        pageSoup = BeautifulSoup(page, "html.parser")
        tabla = pageSoup.find("td", class_="leftCell")
        # Encontrar todos los Nombres de Productos
        Productos = tabla.find_all("a",class_="prominent")
        Producto = []
        for caracter in Productos:
            Producto.append(caracter.text)
        Marcas = tabla.find_all("a",class_="brand")
        Marca = []
        for caracter in Marcas:
            marca_texto = caracter.text.replace("(", "").replace(")", "")
            Marca.append(marca_texto)

        # Check if there are as many brands as products
        if len(Marca) < len(Producto):
            #Append None for missing brands
            Marca += [None] * (len(Producto) - len(Marca))
        # Encontrar las cantidades
        Cantidades = tabla.find_all("div",class_="smallText greyText greyLink")
        Cantidad = []
        for caracter in Cantidades:
            cantidad_texto = caracter.text.replace("\r", "").replace("\n", "").replace("\t", "")
            cantidad_texto = cantidad_texto.split("-", 1)[0]
            Cantidad.append(cantidad_texto)
        # Encontrar las Calorias
        Calorias = tabla.find_all("div", class_="smallText greyText greyLink")
        Caloria = []
        for caracter in Calorias:
            calorias_texto = caracter.text.replace("\r", "").replace("\n", "").replace("\t", "")
            calorias_texto = calorias_texto.split("-", 1)[-1].split("|")[0].strip().replace("Calorías:", "")
            Caloria.append(calorias_texto.strip())
        # Encontrar las Grasas
        Grasas = tabla.find_all("div", class_="smallText greyText greyLink")
        Grasa = []
        for caracter in Grasas:
            grasas_texto = caracter.text.replace("\r", "").replace("\n", "").replace("\t", "")
            grasas_texto = grasas_texto.split("|", 1)[-1].split("|")[0].strip().replace("Grasa:", "")
            Grasa.append(grasas_texto.strip())
        # Encontrar los Carbohidratos
        Carbohidratos = tabla.find_all("div", class_="smallText greyText greyLink")
        Carbohidrato = []
        for caracter in Carbohidratos:
            carbohidratos_texto = caracter.text.replace("\r", "").replace("\n", "").replace("\t", "")
            carbohidratos_texto = carbohidratos_texto.split("|", 2)[-1].split("|")[0].strip().replace("Carbh:", "")
            Carbohidrato.append(carbohidratos_texto.strip())
        # Encontrar las Proteinas
        Proteinas = tabla.find_all("div", class_="smallText greyText greyLink")
        Proteina = []
        for caracter in Proteinas:
            proteinas_texto = caracter.text.replace("\r", "").replace("\n", "").replace("\t", "")
            proteinas_texto = proteinas_texto.split("|", 3)[-1].split("|")[0].strip().replace("Prot:", "")
            proteinas_texto = proteinas_texto.split("g", 1)[0] + "g"
            Proteina.append(proteinas_texto.strip())
        
        
        if not Tabla_Nutricional_Productos.empty:
            columnas = ["Producto","Marca","Cantidad","Caloria","Grasa","Carbohidrato","Proteina"]
            data_ = list(zip(Producto, Marca, Cantidad, Caloria, Grasa, Carbohidrato, Proteina))
            df = pd.DataFrame(columns=columnas,data=data_)
            Tabla_Nutricional_Productos = pd.concat([Tabla_Nutricional_Productos,df],ignore_index=True)
        else:
            columnas = ["Producto","Marca","Cantidad","Caloria","Grasa","Carbohidrato","Proteina"]
            data_ = list(zip(Producto, Marca, Cantidad, Caloria, Grasa, Carbohidrato, Proteina))
            Tabla_Nutricional_Productos = pd.DataFrame(columns= columnas,data=data_)
            
    return Tabla_Nutricional_Productos

# %%
Scraper("https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Leche+Entera&pg=6")
# Out:
#                                       Producto          Marca  \
# 0                         Leche (Leche Entera)  La Serenísima
# 1                                 Leche Entera  La Serenísima
# 2                                 Leche Entera         Tregar
# 3                                 Leche Entera         Ilolay
# 4                                 Leche Entera       Verónica
# ..                                         ...            ...
# 115                             Dulce de Leche           None
# 116          Panecillos de Trigo Entero Inglés           None
# 117  Chocolate y Azúcar (con Leche Descremada)           None
# 118                               Leche Nevada           None
# 119                        Leche Semidesnatada           None
#
#                 Cantidad  Caloria  Grasa Carbohidrato Proteina
# 0            por 1 taza   146kcal  7,93g       11,03g    7,86g
# 1             por 100ml    49kcal  3,00g        4,50g    3,00g
# 2    por 1 vaso (200ml)   114kcal  6,00g        9,00g    6,00g
# 3    por 1 vaso (200ml)   116kcal  6,00g        9,60g    6,00g
# 4    por 1 vaso (200ml)   117kcal  6,00g        9,60g    6,10g
# ..                   ...      ...    ...          ...      ...
# 115           por 100 g   310kcal  5,63g       61,98g    5,15g
# 116     por 1 panecillo   134kcal  1,39g       26,66g    5,81g
# 117          por 1 taza   158kcal  0,70g       29,97g    8,60g
# 118          por 100 ml   114kcal  3,65g       16,53g    3,95g
# 119          por 100 ml    46kcal  1,59g        4,78g    3,12g
#
# [120 rows x 7 columns]

# %%
fallo = "https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q=Aceite&pg=6"
fallor = requests.get(fallo).text
falloSoup = BeautifulSoup(fallor)

# %%
fallo1 = falloSoup.find("div",class_="searchNoResult")
print(fallo1)
# Out:
# None

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup, Tag



def Scraper_v3():
    elementos = ["Aceite","Vinagre","Pasta","Arroz","Legumbre","Semilla","Harina","Premezcla+salada","Polenta","Avena","Atun","Caballa","Paté","Anchoa","Salsa+de+tomate","Salsa","Choclo","Arvejas","Lenteja","Poroto","Garbanzos","Chaucha","Palmitos","Frijoles","Aceitunas","Caldos","Sopas","Purés+instantaneos","Premezclas","Coberturas","Rellenos","Gelatinas","Postres","Dulce+de+Leche","Nutella","Mermeladas","Papas+fritas","Snacks de maiz","Nachos","Maní","Palitos","Galletitas dulces","Bizcochitos","Galletitas de agua","Galletas de arroz","Tostadas","Grisines","Budines","Magdalenas","Yerba","Café","Té","Mate Cocido","Cacao","Azúcar","Edulcorantes","Endulzantes","Cereales","Barritas de cereales","Granola","Chocolates","Alfajores","Caramelos","Gomitas","Chupetines","Bocaditos","Confites","Turrones","Leche entera","Leche descremada","Leche vegetal","Leche en polvo","Yogures enteros","Yogures descremados","Manteca","Levadura","Cremas de leche","Huevos","Tapas","Dulce de membrillo","Dulce de batata","Salchichas","Quesos","Fiambres","Carne vacuna","Pollo","Carne de cerdo","Anchuras","embutidos","Pescados","Mariscos","Frutas","Verduras","Frutos secos","Pan","Pan rallado","Nuggets congeladas","Papas congeladas","Helado"]
    for i in range(len(elementos)):
        if " " in elementos[i]:
            elementos[i] = elementos[i].replace(" ", "+")
    ñomis = []
    for e in elementos:
        ñomis.append(f"https://www.fatsecret.com.ar/calor%C3%ADas-nutrici%C3%B3n/search?q={e}")
    Tabla_Nutricional_Productos = pd.DataFrame()
    for url in ñomis:
        page = requests.get(url)
        soup = BeautifulSoup(page.content, "html.parser")
        tabla_busqueda = soup.find("div",class_="searchResultsPaging")
        if tabla_busqueda is not None:
            res = tabla_busqueda.find_all("a")
            res = [tag.text if isinstance(tag, Tag) else tag for tag in res]
            if "Siguiente" in res:
                res.remove("Siguiente")
            res_int = [int(val) for val in res]
            max_pag = max(res_int)
            link = url + f"&pg={max_pag}"
            url = link
            page = requests.get(url).text
            pageSoup = BeautifulSoup(page, "html.parser")
            
            tabla = pageSoup.find("td", class_="leftCell")
            # Encontrar todos los Nombres de Productos
            Productos = tabla.find_all("a",class_="prominent")
            Producto = []
            for caracter in Productos:
                Producto.append(caracter.text)
            Marcas = tabla.find_all("a",class_="brand")
            Marca = []
            for caracter in Marcas:
                marca_texto = caracter.text.replace("(", "").replace(")", "")
                Marca.append(marca_texto)

            # Check if there are as many brands as products
            if len(Marca) < len(Producto):
                #Append None for missing brands
                Marca += [None] * (len(Producto) - len(Marca))
            # Encontrar las cantidades
            Cantidades = tabla.find_all("div",class_="smallText greyText greyLink")
            Cantidad = []
            for caracter in Cantidades:
                cantidad_texto = caracter.text.replace("\r", "").replace("\n", "").replace("\t", "")
                cantidad_texto = cantidad_texto.split("-", 1)[0]
                Cantidad.append(cantidad_texto)
            # Encontrar las Calorias
            Calorias = tabla.find_all("div", class_="smallText greyText greyLink")
            Caloria = []
            for caracter in Calorias:
                calorias_texto = caracter.text.replace("\r", "").replace("\n", "").replace("\t", "")
                calorias_texto = calorias_texto.split("-", 1)[-1].split("|")[0].strip().replace("Calorías:", "")
                Caloria.append(calorias_texto.strip())
            # Encontrar las Grasas
            Grasas = tabla.find_all("div", class_="smallText greyText greyLink")
            Grasa = []
            for caracter in Grasas:
                grasas_texto = caracter.text.replace("\r", "").replace("\n", "").replace("\t", "")
                grasas_texto = grasas_texto.split("|", 1)[-1].split("|")[0].strip().replace("Grasa:", "")
                Grasa.append(grasas_texto.strip())
            # Encontrar los Carbohidratos
            Carbohidratos = tabla.find_all("div", class_="smallText greyText greyLink")
            Carbohidrato = []
            for caracter in Carbohidratos:
                carbohidratos_texto = caracter.text.replace("\r", "").replace("\n", "").replace("\t", "")
                carbohidratos_texto = carbohidratos_texto.split("|", 2)[-1].split("|")[0].strip().replace("Carbh:", "")
                Carbohidrato.append(carbohidratos_texto.strip())
            # Encontrar las Proteinas
            Proteinas = tabla.find_all("div", class_="smallText greyText greyLink")
            Proteina = []
            for caracter in Proteinas:
                proteinas_texto = caracter.text.replace("\r", "").replace("\n", "").replace("\t", "")
                proteinas_texto = proteinas_texto.split("|", 3)[-1].split("|")[0].strip().replace("Prot:", "")
                proteinas_texto = proteinas_texto.split("g", 1)[0] + "g"
                Proteina.append(proteinas_texto.strip())
        
        
            if not Tabla_Nutricional_Productos.empty:
                columnas = ["Producto","Marca","Cantidad","Caloria","Grasa","Carbohidrato","Proteina"]
                data_ = list(zip(Producto, Marca, Cantidad, Caloria, Grasa, Carbohidrato, Proteina))
                df = pd.DataFrame(columns=columnas,data=data_)
                Tabla_Nutricional_Productos = pd.concat([Tabla_Nutricional_Productos,df],ignore_index=True)
            else:
                columnas = ["Producto","Marca","Cantidad","Caloria","Grasa","Carbohidrato","Proteina"]
                data_ = list(zip(Producto, Marca, Cantidad, Caloria, Grasa, Carbohidrato, Proteina))
                Tabla_Nutricional_Productos = pd.DataFrame(columns= columnas,data=data_)
            
    return Tabla_Nutricional_Productos

# %%
Scraper_v3()
# Out:
#                                           Producto           Marca  \
# 0       Filetes de Atún en Aceite de Oliva con Ajo  Gomes da Costa
# 1                                Caballa en Aceite        Caracas
# 2                                Merluza en Aceite         Puglisi
# 3                     Aceite de Oliva Virgen Extra      La Toscana
# 4    Aderezo Italiano (Hecho con Aceite y Vinagre)         Pennisi
# ..                                             ...             ...
# 603                            Papas Deshidratadas            None
# 604           Frambuesas Congeladas sin Endulzante            None
# 605                             Cerezas Congeladas            None
# 606                   Fresas Congeladas con Azúcar            None
# 607                              Fresas Congeladas            None
#
#                              Cantidad  Caloria   Grasa Carbohidrato Proteina
# 0     por 3 cucharadas soperas (60g)   124kcal   6,10g        0,00g   17,00g
# 1           por 1/4 taza de té (55g)   125kcal  10,00g        0,00g    8,30g
# 2    por 3 cucharadas soperas) (60g)    99kcal   5,00g        0,00g   14,00g
# 3        por 1 cuchara sopera (13ml)   108kcal  12,00g        0,00g    0,00g
# 4                    por 1 cucharada    43kcal   4,17g        1,53g    0,06g
# ..                                ...      ...     ...          ...      ...
# 603                    por 1 porción   102kcal   5,37g       12,75g    1,31g
# 604                       por 1 taza   130kcal   1,62g       29,85g    3,00g
# 605              por 1 porción de 10    23kcal   0,22g        5,62g    0,47g
# 606                       por 1 taza   222kcal   0,36g       59,82g    1,33g
# 607                       por 1 taza   222kcal   0,36g       59,82g    1,33g
#
# [608 rows x 7 columns]
